# %% [markdown]
# <a href="https://colab.research.google.com/github/anderson02aa/Pos_de_IA_na_UFV-2024/blob/main/ELT574_11850_3_Atividade_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <H1><center><b>[Atividade1-Pós_UFV]-ELT 574-APRENDIZADO_DE_MaQUINA</b></center></H1>
# <p>
# *   Nome: Anderson Alves de Albuquerque<br>
# *   Data: junho de 2024<br>
# *   Professor(es): Rodolpho Neves.<br>
# *   Este trabalho foi realizado para compor a avaliação (nota) na disciplina APRENDIZADO_DE_MaQUINA da Pós-graduação em IA.
# </p><br>

# %% [markdown]
# <p><h9>OBS1: a URL do <i>notebook</i> desse projeto no Colab é <a href="https://colab.research.google.com/drive/19D3o_yM0jEYq1atf1C2x_AoreAZYuJnw?usp=sharing">https://colab.research.google.com/drive/19D3o_yM0jEYq1atf1C2x_AoreAZYuJnw?usp=sharing</a>
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;a URL do <i>notebook</i> desse projeto no GitHub é <a href="https://github.com/anderson02aa/Pos_de_IA_na_UFV-2024/blob/main/ELT574_11850_3_Atividade_1.ipynb">https://github.com/anderson02aa/Pos_de_IA_na_UFV-2024/blob/main/ELT574_11850_3_Atividade_1.ipynb</a></h9></p>

# %% [markdown]
# <p><h2><b><font color=#FF0000>OBS2: o desenvolvimento final para responder as perguntas se concentrou mais no item 5, as respostas finais estão no item 6.
# </font>
# </b></h2></p>

# %% [markdown]
# # <b>1. Definição do Problema</b>

# %% [markdown]
# ##<b>1.1. Definições do projeto:</b>

# %% [markdown]
# <p align="justify">&emsp;Esse <i>dataset</i> foi fornecido pelo professor da disciplina e foi armazenado nesta conta do GitHub em https://github.com/anderson02aa/Pos_de_IA_na_UFV-2024/blob/dedcb098f5cedc6ec9e76fe847f86f6afe5dfde2/ELT574-melb_data.csv.
# </p>

# %% [markdown]
# <p align="justify">&emsp;Originalmente esse Dataset está em https://www.kaggle.com/datasets/dansbecker/melbourne-housing-snapshot </p>

# %% [markdown]
# <p><b>Enunciado desta atividade 1:</b></p>
# <p align="justify">&emsp;Baixe o dataset  "melbourne-housing-snapshot" e, com o foco para a estimação do preço dos imóveis, faça o que se pede:</p>
#
# <p align="justify">&emsp;Crie um Notebook no Google Colab com o nome [ELT574 <Matrícula> Atividade 1], modificando o campo <Matrícula> pela sua matrícula do Sapiens (Exemplo: ELT574 12700-0 Atividade 1). Faça o que se pede, conforme o roteiro abaixo:</p>
# <p align="justify">&emsp;Crie uma variável relacionando duas outras variáveis do dataset, como mostrado em exemplo na aula síncrona (sugestões de variáveis: número de famílias, total de quartos e total de cômodos) e calcule o coeficiente de correlação linear entre ela e a variável alvo.</p>
# <p align="justify">&emsp;A variável criada possui algum grau de correlação linear relevante com a variável alvo? O que pode ser explicado por esta correlação?</p>
# <p align="justify">&emsp;Todas as questões devem ser inseridas no notebook do Google Colab. O link para o notebook deve ser enviado como resposta da tarefa.</p>

# %% [markdown]
# ##<b>1.2. Atributos do <i> dataset</i>:</b>

# %% [markdown]
# <p><b>Definir cada um dos atributos do <i>dataset</i> (Tabela 1):</b></p>
# <table border="2">
# <tr><th>Item</th><th>Atributos</th><th align="left">&emsp;&emsp;Descrição dos atributos</th></tr>
# <tr><td>01</td><td>Suburb</td><td>Nome do subúrbio.</td>
# </tr>
# <tr><td>02</td><td>Address</td><td>Endereço do imóvel no padrão dos EUA (Estados Unidos da América).</td></tr>
# <tr><td>03</td><td>Rooms</td><td>Quantidade de quartos.</td>
# </tr>
# <tr><td>04</td><td>Type</td><td>Tipo.</td>
# </tr>
# <tr><td>05</td><td>Price</td><td>Preço do aluguel.</td>
# </tr>
# <tr><td>06</td><td>Method</td><td>Método.</td>
# </tr>
# <tr><td>07</td><td>SellerG</td><td>SellerG.</td>
# </tr>
# <tr><td>08</td><td>Date</td><td>Data.</td>
# </tr>
# <tr><td>09</td><td>Distance</td><td>Distância.</td>
# </tr>
# <tr><td>10</td><td>Postcode</td><td>Caixa postal.</td>
# </tr>
# <tr><td>11</td><td>Bedroom2</td><td>Quantidade de quartos.</td>
# </tr>
# <tr><td>12</td><td>Bathroom</td><td>Quantidade de banheiros.</td>
# </tr>
#
# <tr><td>13</td><td>Car</td><td>Quantidade de carros.</td>
# </tr>
# <tr><td>14</td><td>Landsize</td><td>Área/tamanho total.</td>
# </tr>
# <tr><td>15</td><td>BuildingArea</td><td>Área/tamanho Construída.</td>
# </tr>
# <tr><td>16</td><td>YearBuilt</td><td>Ano da construção.</td>
# </tr>
# <tr><td>17</td><td>CouncilArea</td><td>Área do Conselho.</td>
# </tr>
# <tr><td>18</td><td>Lattitude</td><td>Latitude.</td>
# </tr>
#
# <tr><td>19</td><td>Longtitude</td><td>Longtitude.</td>
# </tr>
# <tr><td>20</td><td>Regionname</td><td>Nome da região.</td>
# </tr>
# <tr><td>21</td><td>Propertycount</td><td>Quantidade de moradores.</td>
# </tr>
#
# </table>
# <tfoot><b>Tabela 1: descrição dos atributos (coluna) do <i>dataset</i> do arquivo CSV</b></tfoot>
# <br>

# %% [markdown]
# ##<b>1.3. Código em python para importação de bibliotecas:</b>

# %% [markdown]
# </p><p align="justify">&emsp;Instalando alguns pacotes que são necessários antes da importação de bibliotecas:</p>

# %%
# Instalando Pacotes
# !pip install pandas
# !pip install seaborn
# !pip install matplotlib
# !pip install numpy

# %% [markdown]
# </p><p align="justify">&emsp;Importando bibliotecas que serão necessárias durante este trabalho:</p>

# %%
############################################################################
# Imports das bibliotecas Pandas, Numpy, Missingno, Searborn e Metaplotlib.
############################################################################
## NumPy para manipular matrizes e vetores
import numpy as np

## Pandas para manipular os dataframes
import pandas as pd

## Plotar figuras bonitas
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)
import seaborn as sns

print('Setup completo!')
# Out:
# Setup completo!

# %% [markdown]
# ##<br><b>1.4. Exibição de <i>warnings:</i></b>

# %% [markdown]
# <p align="justify">&emsp;Configuração para não exibir os <i><u>warnings</u></i> durante execução de comandos.</p>

# %%
# configuração para não exibir os warnings
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# #<b><i>2. Carga de Dados:</i></b>

# %% [markdown]
# ##<b><i>2.1. Carregando <i>dataset</i> de um arquivo .CSV</i></b>

# %% [markdown]
# <p align="justify">&emsp;Utilizar pacote Pandas (<i><u>Python Data Analysis Library</u></i>) para carregar um arquivo ".csv" indicado pela variável "url".</p>
# <p align="justify">&emsp;Com o <i>dataset</i> carregado, será possível  explorar esse <i>dataset</i> um pouco.</p>

# %%
#Importando as bibliotecas para analise do problema e configurando o notebook

## OS para executar comandos de diretorio
# import os

## Habilitar Google Drive no Colab
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# baixar o arquivo do GitHub
# o repositorio alvo eh o repositorio da disciplina
# !wget https://raw.githubusercontent.com/anderson02aa/Pos_de_IA_na_UFV-2024/main/ELT574-melb_data.csv
# Out:
# --2024-06-20 04:53:44--  https://raw.githubusercontent.com/anderson02aa/Pos_de_IA_na_UFV-2024/main/ELT574-melb_data.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2091239 (2.0M) [text/plain]
# Saving to: ‘ELT574-melb_data.csv.1’
#
# ELT574-melb_data.cs 100%[===================>]   1.99M  --.-KB/s    in 0.008s
#
# 2024-06-20 04:53:44 (237 MB/s) - ‘ELT574-melb_data.csv.1’ saved [2091239/2091239]

# %%
## Importar os dados do banco de dados
# path do Google Drive
# path = '/content/drive/MyDrive/1-UFV/Disciplinas/Disciplinas Lato-Sensu/ELT 574 - Aprendizado de máquinas/Material da disciplina/Roteiros e aulas/Atividades/housing.csv'
# path do arquivo baixado do GitHub
path='/content/ELT574-melb_data.csv'

#df_melb=pd.read_csv(path)
#Lê o arquivo utilizando as colunas informadas:
#dataset = pd.read_csv(path, skiprows=[0,1], delimiter=',' , encoding='iso-8859-1')
dataset = pd.read_csv(path,  delimiter=',' , encoding='iso-8859-1')

## Lê o arquivo utilizando as colunas informadas:
##dataset = pd.read_csv(url, names=colunas, skiprows=[0,1], delimiter=',' , nrows=13577 , nrows=19)

print('Dataset carregado!')

dataset.head()
# Out:
# Dataset carregado!
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 1  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 2  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
# 3  4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0           NaN
# 4  4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0         142.0
#
# ...

# %%
dataset.tail()
# Out:
#               Suburb        Address  Rooms Type      Price Method   SellerG  \
# 13575  Wheelers Hill   12 Strada Cr      4    h  1245000.0      S     Barry
# 13576   Williamstown  77 Merrett Dr      3    h  1031000.0     SP  Williams
# 13577   Williamstown    83 Power St      3    h  1170000.0      S     Raine
# 13578   Williamstown   96 Verdon St      4    h  2500000.0     PI   Sweeney
# 13579     Yarraville     6 Agnes St      4    h  1285000.0     SP   Village
#
#              Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# 13575  26/08/2017      16.7    3150.0  ...       2.0  2.0     652.0
# 13576  26/08/2017       6.8    3016.0  ...       2.0  2.0     333.0
# 13577  26/08/2017       6.8    3016.0  ...       2.0  4.0     436.0
# 13578  26/08/2017       6.8    3016.0  ...       1.0  5.0     866.0
# 13579  26/08/2017       6.3    3013.0  ...       1.0  1.0     362.0
#
#        BuildingArea  YearBuilt  CouncilArea Lattitude  Longtitude  \
# ...

# %%
# Carrega arquivo csv usando Pandas usando uma URL.
# Informa a URL de importação do dataset:
#url="https://github.com/anderson02aa/Pos_de_IA_na_UFV-2024/blob/dedcb098f5cedc6ec9e76fe847f86f6afe5dfde2/ELT574-melb_data.csv"

# Informa o cabeçalho das colunas:
#colunas=['Suburb','Address','Rooms','Type','Price','Method','SellerG','Date','Distance','Postcode','Bedroom2','Bathroom','Car','Landsize','BuildingArea','YearBuilt','CouncilArea','Lattitude','Longtitude','Regionname','Propertycount']

# Lê o arquivo utilizando as colunas informadas:
#dataset = pd.read_csv(url, names=colunas, skiprows=[0,1], delimiter=',')

# %% [markdown]
# ##<b><i>2.2. Mostrando o início do <i>dataset</i> com <i>head()<i>:</i></b>

# %%
# mostra os 11 primeiros registros do dataset.
dataset.head(3)
# Out:
#        Suburb          Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford     85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford  25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford     5 Charles St      3    h  1465000.0     SP  Biggin
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 1  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 2  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# 0        NaN        Yarra  -37.7996    144.9984  Northern Metropolitan
# 1     1900.0        Yarra  -37.8079    144.9934  Northern Metropolitan
# 2     1900.0        Yarra  -37.8093    144.9944  Northern Metropolitan
#
#   Propertycount
# 0        4019.0
# 1        4019.0
# 2        4019.0
#
# ...

# %% [markdown]
# ##<br><b><i>2.3. Mostrando o final do <i>dataset</i> com <i>tail()<i>:</i></b>

# %%
# mostra os 11 últimos registros do dataset.
dataset.tail(3)
# Out:
#              Suburb       Address  Rooms Type      Price Method  SellerG  \
# 13577  Williamstown   83 Power St      3    h  1170000.0      S    Raine
# 13578  Williamstown  96 Verdon St      4    h  2500000.0     PI  Sweeney
# 13579    Yarraville    6 Agnes St      4    h  1285000.0     SP  Village
#
#              Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# 13577  26/08/2017       6.8    3016.0  ...       2.0  4.0     436.0
# 13578  26/08/2017       6.8    3016.0  ...       1.0  5.0     866.0
# 13579  26/08/2017       6.3    3013.0  ...       1.0  1.0     362.0
#
#        BuildingArea  YearBuilt  CouncilArea Lattitude  Longtitude  \
# 13577           NaN     1997.0          NaN -37.85274   144.88738
# 13578         157.0     1920.0          NaN -37.85908   144.89299
# 13579         112.0     1920.0          NaN -37.81188   144.88449
#
#                  Regionname Propertycount
# 13577  Western Metropolitan        6380.0
# 13578  Western Metropolitan        6380.0
# ...

# %% [markdown]
# ##<br><b><i>2.4. Ordenação ascendente pelo valor da mensalidade do <i>dataset</i>:</i></b>

# %%
#Ordena pela coluna "Date" de forma descendente:
dataset.sort_values("Date", ascending=False )
# Out:
#            Suburb              Address  Rooms Type      Price Method  \
# 12497     Fitzroy          101 Kerr St      3    h  1750000.0     VB
# 12555     Mentone        14A Teague Av      3    t   875000.0      S
# 12543    Kew East            29 Elm Gr      3    h  1655000.0     SA
# 12542    Kew East        11 Coleman Av      4    h  2000000.0     VB
# 12541    Kew East       38 Bennett Pde      3    h  1700000.0      S
# ...           ...                  ...    ...  ...        ...    ...
# 8957      Sunbury     11 Bannermann St      4    h   580000.0      S
# 8956   Strathmore        2/30 Bulla Rd      2    h   646000.0      S
# 8830     Hawthorn          7/28 Elm St      1    u   395000.0      S
# 8831     Hawthorn  1/514 Glenferrie Rd      3    u  1000000.0      S
# 8793      Donvale        1 Bernarra Ct      7    h  2705000.0      S
#
#              SellerG       Date  Distance  Postcode  ...  Bathroom  Car  \
# ...

# %%
#Ordena pela coluna "Date" de forma descendente:
dataset.sort_values("Date", ascending=True )
# Out:
#                 Suburb              Address  Rooms Type      Price Method  \
# 8754           Bulleen      80 Thompsons Rd      3    h  1060000.0      S
# 8830          Hawthorn          7/28 Elm St      1    u   395000.0      S
# 8831          Hawthorn  1/514 Glenferrie Rd      3    u  1000000.0      S
# 8832          Hawthorn   8/3 Kooyongkoot Rd      2    u   450000.0      S
# 8833          Hawthorn       63 Liddiard St      4    h  2900000.0      S
# ...                ...                  ...    ...  ...        ...    ...
# 12502  Frankston South       24 Sycamore Rd      4    h   830000.0     SP
# 12503         Gisborne        15 Morilla Ct      3    h   690000.0     VB
# 12504         Gisborne      204 Panorama Dr      4    h   780000.0      S
# 12506   Gladstone Park          7 Dudley Ct      3    h   625000.0     SP
# 12535      Keilor East       20 College Pde      4    h  1210000.0      S
#
#          SellerG       Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# ...

# %% [markdown]
# #<br><b>3. Análise de Dados:</b>

# %% [markdown]
# <p align="justify">&emsp;Nesta seção será realizada análise de dados.</p>

# %% [markdown]
# ##<b>3.1. Estatísticas Descritivas:</b>

# %% [markdown]
# <p align="justify">&emsp;Examinar as dimensões do <i>dataset</i>, suas informações e alguns exemplos de linhas.</p>

# %% [markdown]
# ###<b>3.1.1. Dimensões:</b>

# %% [markdown]
# <p align="justify">&emsp;Formato da saída: (linha, coluna)</p>

# %%
# Mostra as dimensões do dataset.
print(dataset.shape)
# Out:
# (13580, 21)

# %%
xn=len (dataset.columns)
print ("Quantidade de colunas: ", xn)
# Out:
# Quantidade de colunas:  21

# %%
xn=len(dataset.index)
print (f'Quantidade de linhas: {xn} ' )
# Out:
# Quantidade de linhas: 13580

# %% [markdown]
# ###<b>3.1.2. Informações:</b>

# %% [markdown]
# <p align="justify">&emsp;Nesse exemplo será possível saber os nomes das colunas (<i><u>Column</u></i>), quantidade de colunas campos não nulos em cada coluna (<i><u>Non-Null</u></i>) e tipagem da coluna (<i><u>Dtype</u></i>).

# %%
# Mostra as informações do dataset.
print(dataset.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         13580 non-null  object
#  1   Address        13580 non-null  object
#  2   Rooms          13580 non-null  int64
#  3   Type           13580 non-null  object
#  4   Price          13580 non-null  float64
#  5   Method         13580 non-null  object
#  6   SellerG        13580 non-null  object
#  7   Date           13580 non-null  object
#  8   Distance       13580 non-null  float64
#  9   Postcode       13580 non-null  float64
#  10  Bedroom2       13580 non-null  float64
#  11  Bathroom       13580 non-null  float64
#  12  Car            13518 non-null  float64
#  13  Landsize       13580 non-null  float64
#  14  BuildingArea   7130 non-null   float64
#  15  YearBuilt      8205 non-null   float64
#  16  CouncilArea    12211 non-null  object
# ...

# %% [markdown]
# ###<b>3.1.3. Mostrar os tipos dos atributos (tipagem):</b>

# %%
# Verifica o tipo de dataset de cada atributo.
dataset.dtypes
# Out:
# Suburb            object
# Address           object
# Rooms              int64
# Type              object
# Price            float64
# Method            object
# SellerG           object
# Date              object
# Distance         float64
# Postcode         float64
# Bedroom2         float64
# Bathroom         float64
# Car              float64
# Landsize         float64
# BuildingArea     float64
# YearBuilt        float64
# CouncilArea       object
# Lattitude        float64
# Longtitude       float64
# Regionname        object
# Propertycount    float64
# dtype: object

# %% [markdown]
# ###<b>3.1.4. Estatística básica do <i>dataset</i>:</b>

# %% [markdown]
# <p align="justify">&emsp;Mostra uma estatística básica do <i><u>dataset</u></i>: quatidade máxima de itens, quatidade mínima de itens, médias e <i><u>quartis</u></i>.
# </p>

# %%
# Faz um resumo estatístico do dataset (média, desvio padrão, mínimo, máximo e os quartis)
dataset.describe()
# Out:
#               Rooms         Price      Distance      Postcode      Bedroom2  \
# count  13580.000000  1.358000e+04  13580.000000  13580.000000  13580.000000
# mean       2.937997  1.075684e+06     10.137776   3105.301915      2.914728
# std        0.955748  6.393107e+05      5.868725     90.676964      0.965921
# min        1.000000  8.500000e+04      0.000000   3000.000000      0.000000
# 25%        2.000000  6.500000e+05      6.100000   3044.000000      2.000000
# 50%        3.000000  9.030000e+05      9.200000   3084.000000      3.000000
# 75%        3.000000  1.330000e+06     13.000000   3148.000000      3.000000
# max       10.000000  9.000000e+06     48.100000   3977.000000     20.000000
#
#            Bathroom           Car       Landsize  BuildingArea    YearBuilt  \
# count  13580.000000  13518.000000   13580.000000   7130.000000  8205.000000
# mean       1.534242      1.610075     558.416127    151.967650  1964.684217
# ...

# %%
dataset.shape
# Out:
# (13580, 21)

# %% [markdown]
# ###<b>3.1.5. Estatística básica do <i>dataset</i> com tratamento básico:</b>

# %% [markdown]
# <p align="justify">&emsp;Converte para "<i><u>string</u></i>" as colunas que não precisam entrar na estatística e terem seus gráficos gerados: "<u>edad</u>" e "<u>enfermedad_coronaria</u>".</p>

# %%
#Converte para "string" as colunas que não precisam entrar na estatística e terem seus gráficos gerados: "Address" e "Suburb".
# Inclusive, agora as suas médias não serão geradas.
##dataset['Address'] = dataset['Address'].map(str) # Age agora será string, então não entra na saida do descibe().
dataset['Suburb'] = dataset['Suburb'].map(str) # Weight agora será string, então não entra na saida do descibe().
# Agora utilizar o dataset.info():
dataset.describe()
# Out:
#               Rooms         Price      Distance      Postcode      Bedroom2  \
# count  13580.000000  1.358000e+04  13580.000000  13580.000000  13580.000000
# mean       2.937997  1.075684e+06     10.137776   3105.301915      2.914728
# std        0.955748  6.393107e+05      5.868725     90.676964      0.965921
# min        1.000000  8.500000e+04      0.000000   3000.000000      0.000000
# 25%        2.000000  6.500000e+05      6.100000   3044.000000      2.000000
# 50%        3.000000  9.030000e+05      9.200000   3084.000000      3.000000
# 75%        3.000000  1.330000e+06     13.000000   3148.000000      3.000000
# max       10.000000  9.000000e+06     48.100000   3977.000000     20.000000
#
#            Bathroom           Car       Landsize  BuildingArea    YearBuilt  \
# count  13580.000000  13518.000000   13580.000000   7130.000000  8205.000000
# mean       1.534242      1.610075     558.416127    151.967650  1964.684217
# ...

# %% [markdown]
# <br>
# <p align="justify">&emsp;Agora a estatística básica do <i><u>dataset</u></i> por Preço (agrupado por idade):</p>

# %%
# estatística básica do dataset sobre infarto:
dataset.loc[:,["Suburb","Price"]].groupby("Price").describe()
# Out:
#           Suburb
#            count unique          top freq
# Price
# 85000.0        1      1    Footscray    1
# 131000.0       1      1    Caulfield    1
# 145000.0       2      2       Coburg    1
# 160000.0       1      1     Hawthorn    1
# 170000.0       2      2    Footscray    1
# ...          ...    ...          ...  ...
# 6400000.0      1      1  Middle Park    1
# 6500000.0      1      1          Kew    1
# 7650000.0      1      1     Hawthorn    1
# 8000000.0      1      1   Canterbury    1
# 9000000.0      1      1     Mulgrave    1
#
# [2204 rows x 4 columns]

# %% [markdown]
# ###<b>3.1.6. Verificar se as classes estão balanceadas:</b>

# %% [markdown]
# <p align="justify">&emsp;Vamos agora verificar se o <i>dataset</i> tem as classes balanceadas para que possamos tratar o desbalanceamento posteriormente, se necessário. Além disso, é possível ver os máximos e mínimos de cada classe.</p>

# %%
print("======================================")
# distribuição das a coluna "genero"
print(dataset.groupby('Suburb').size())
print("======================================")
# distribuição das a coluna "edad"
print(dataset.groupby('Address').size())
print("======================================")
# distribuição das a coluna "hipertensión"
print(dataset.groupby('Date').size())
print("======================================")
# distribuição das a coluna "enfermedad_coronaria"
print(dataset.groupby('Price').size())
print("======================================")
# distribuição das a coluna "casado"
print(dataset.groupby('CouncilArea').size())
print("======================================")
# distribuição das a coluna "trabajo"
print(dataset.groupby('Rooms').size())
print("======================================")
# distribuição das a coluna "residencia"
print(dataset.groupby('Bathroom').size())
print("======================================")
# Out:
# ...
# Suburb
# Abbotsford       56
# Aberfeldie       44
# Airport West     67
# Albanvale         6
# Albert Park      69
#                ...
# Wonga Park        1
# Wyndham Vale      4
# Yallambie        24
# Yarra Glen        1
# Yarraville      164
# Length: 314, dtype: int64
# ...
# Address
# 1 Adelle Ct        1
# 1 Airlie St        1
# 1 Albion Ct        1
# 1 Alexander St     1
# 1 Alma St          1
#                   ..
# 9a Elizabeth St    1
# 9a Ivan Av         1
# 9a Russell St      1
# 9a The Crossway    1
# 9b Stewart St      1
# Length: 13378, dtype: int64
# ...
# Date
# 1/07/2017     276
# 10/09/2016    235
# 10/12/2016    319
# 11/02/2017     84
# 11/03/2017     38
# 12/06/2016     46
# 12/08/2017    387
# 12/11/2016    292
# 13/05/2017    255
# 13/08/2016    132
# 14/05/2016    193
# 15/07/2017    292
# 15/10/2016    300
# 16/04/2016    217
# 16/07/2016    141
# 16/09/2017    254
# 17/06/2017    374
# 17/09/2016    242
# 18/03/2017    303
# 18/06/2016    261
# 19/08/2017    201
# ...

# %% [markdown]
# ###<b>3.2. Histograma:</b>

# %%
# Distribuicao das frequencias
dataset.hist(bins=50, figsize=(20,15))
plt.show()

# %% [markdown]
# ###<b>3.2.1. Com mediana:</b>

# %%
sns.histplot(data=dataset,x='Price',kde=True)
# Out:
# <Axes: xlabel='Price', ylabel='Count'>

# %% [markdown]
# ###<b>3.3. Gráficos de densidade:</b>

# %% [markdown]
# <p align="justify">&emsp;O Gráfico de Densidade, ou <i><u>Density Plot</u></i>, é bem parecido com o histograma, mas com uma visualização um pouco diferente. Com ele, pode ser mais fácil identificar a distribuição do atributos do <i><u>dataset</u></i>. Assim como foi realizado com o histograma, vamos criar um <i><u>density plot</u></i> para cada atributo do <i><u>dataset</u></i>.</p>
#
# <p align="justify">&emsp;Veremos que muitos dos atributos têm uma distribuição distorcida. Uma transformação como a <i><u>Box-Cox</u></i>, que pode aproximar a distribuição de uma Normal, pode ser útil neste caso.</p>

# %%
# Density Plot
#datasetnovo.plot(kind = 'density', subplots = True, layout = (4,3), sharex = False, figsize = (16,12),linewidth=2)
dataset.plot(kind = 'density', subplots = True, layout = (11,2), sharex = False, figsize = (14,12),linewidth=2)
plt.show()

# %% [markdown]
# <br>

# %% [markdown]
# ###<b><i>3.4. Scatter plot</i>:</b>

# %% [markdown]
# <p align="justify">&emsp;Por sua vez, o gráfico de dispersão (<em><b><u>scatter plot</u></b></em>) mostra o relacionamento entre duas variáveis. Vamos exibir um para cada par de atributos dos <i><u>dataset</u></i>, usando o <em><u>Seaborn</u></em>.</p>
# <br>

# %%
# Scatter Plot com Seaborn - Variação 1
sns.pairplot(dataset)

# %% [markdown]
# #<b>4. Pré-Processamento de dados:</b>

# %% [markdown]
# <p align="justify">&emsp;Nesta etapa, poderíamos realizar diversas operações de preparação de dados, como por exemplo, tratamento de valores <i><u>missings</u></i> (faltantes), limpeza de dados, transformações como <i><u>one-hot-encoding</u></i>, seleção de características (<i><u>feature selection</u></i>), entre outras não mostradas neste <i><u>notebook</u></i>.</p>

# %% [markdown]
# ##<b>4.1. Tratamento de <i>Missings</i> e Limpeza:</b>

# %% [markdown]
# <p align="justify">&emsp;O <u><i>dataset</i></u> "infarto" tem <i><u>missings</u></i> aparentes em algumas colunas. Então, vamos fazer um tratamento de dados e criar uma nova visão do nosso <u><i>dataset</i></u>.</p>

# %%
# verificando nulls no dataset
#datasetnovo.isnull().sum()
dataset.isnull().sum()
# Out:
# Suburb              0
# Address             0
# Rooms               0
# Type                0
# Price               0
# Method              0
# SellerG             0
# Date                0
# Distance            0
# Postcode            0
# Bedroom2            0
# Bathroom            0
# Car                62
# Landsize            0
# BuildingArea     6450
# YearBuilt        5375
# CouncilArea      1369
# Lattitude           0
# Longtitude          0
# Regionname          0
# Propertycount       0
# dtype: int64

# %% [markdown]
# ###<b>4.1.1. Achar a quantidade de linhas contendo nulos:</b>

# %%
datasetnovo=dataset.drop("Suburb", axis=1)
datasetnovo=datasetnovo.drop("Address", axis=1)
datasetnovo=datasetnovo.drop("Type", axis=1)
datasetnovo=datasetnovo.drop("Method", axis=1)
datasetnovo=datasetnovo.drop("SellerG", axis=1)
datasetnovo=datasetnovo.drop("Distance", axis=1)
datasetnovo=datasetnovo.drop("Postcode", axis=1)
datasetnovo=datasetnovo.drop("Car", axis=1)
datasetnovo=datasetnovo.drop("Bathroom", axis=1)
datasetnovo=datasetnovo.drop("Date", axis=1)
datasetnovo=datasetnovo.drop("CouncilArea", axis=1)
datasetnovo=datasetnovo.drop("Lattitude", axis=1)
datasetnovo=datasetnovo.drop("Longtitude", axis=1)
datasetnovo=datasetnovo.drop("Regionname", axis=1)
datasetnovo=datasetnovo.drop("Propertycount", axis=1)

# %%
## Verifica quais valores são nulos em todas as colunas.
null_cols = dataset.isna() #,'LandSize','BuildingArea','YearBuilt','Rooms','Bedroom2']].isna()
## Verifica quais linhas têm valores nulos em todas as colunas.
all_null_rows = null_cols.all(axis=1)
## Calcula a quantidade de linhas que contém nulos em todas as colunas.
quantidade = all_null_rows.sum()
print("==> Quantidade de linhas com nulos nas colunas: ", quantidade)
dataset.info()
# Out:
# ==> Quantidade de linhas com nulos nas colunas:  0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         13580 non-null  object
#  1   Address        13580 non-null  object
#  2   Rooms          13580 non-null  int64
#  3   Type           13580 non-null  object
#  4   Price          13580 non-null  float64
#  5   Method         13580 non-null  object
#  6   SellerG        13580 non-null  object
#  7   Date           13580 non-null  object
#  8   Distance       13580 non-null  float64
#  9   Postcode       13580 non-null  float64
#  10  Bedroom2       13580 non-null  float64
#  11  Bathroom       13580 non-null  float64
#  12  Car            13518 non-null  float64
#  13  Landsize       13580 non-null  float64
#  14  BuildingArea   7130 non-null   float64
#  15  YearBuilt      8205 non-null   float64
# ...

# %% [markdown]
# ###<b>4.2. Correlação:</b>

# %%
datasetnovo=dataset.drop("Suburb", axis=1)
datasetnovo=datasetnovo.drop("Address", axis=1)
datasetnovo=datasetnovo.drop("Type", axis=1)
datasetnovo=datasetnovo.drop("Method", axis=1)
datasetnovo=datasetnovo.drop("SellerG", axis=1)
datasetnovo=datasetnovo.drop("Postcode", axis=1)
datasetnovo=datasetnovo.drop("Car", axis=1)
###datasetnovo=datasetnovo.drop("Bathroom", axis=1)
datasetnovo=datasetnovo.drop("Date", axis=1)
datasetnovo=datasetnovo.drop("CouncilArea", axis=1)
datasetnovo=datasetnovo.drop("Lattitude", axis=1)
datasetnovo=datasetnovo.drop("Longtitude", axis=1)
datasetnovo=datasetnovo.drop("Regionname", axis=1)
datasetnovo=datasetnovo.drop("Propertycount", axis=1)

# %%
#LandSize  BuildingArea  YearBuilt   Rooms  Bedroom2
# Transforma a coluna genero que string em Discreto: feminino recebe 1, masculino 2 e outros recebe 3.
#datasetnovo['genero'] = datasetnovo['genero'].replace({'Femenino': 1, 'Masculino': 2,'Other':3}).astype(int)

# %% [markdown]
# #<b>5. Criando nova coluna (variável) para o dataset chamado "datasetnovo":</b>

# %% [markdown]
# ##5.1. Nova variável chamada "Total_comodos" sendo criada.

# %%
datasetnovo["total_comodos"]=datasetnovo["Bedroom2"]+datasetnovo["Rooms"]+datasetnovo["Bathroom"]

# %% [markdown]
# ##5.2.Criando a matriz de correlação.

# %%
# Matriz de Correlação com Matplotlib Seaborn: sns.heatmap(datasetnovo.corr(), annot=True, cmap='RdBu');
# Calculando a matriz de correlação do novo DataFrame
corr = datasetnovo.corr()
# Gerando o heatmap de correlação
plt.figure(figsize=(10, 8))
sns.heatmap(corr, annot=True, cmap='RdBu')
plt.show()

# %% [markdown]
# ##5.3. Gerando lista com as correlações:

# %%
corr['Price'].sort_values(ascending=False)
# Out:
# Price            1.000000
# total_comodos    0.529784
# Rooms            0.496634
# Bedroom2         0.475951
# Bathroom         0.467038
# BuildingArea     0.090981
# Landsize         0.037507
# Distance        -0.162522
# YearBuilt       -0.323617
# Name: Price, dtype: float64

# %% [markdown]
# ##5.4.Gerar gráfico: total_comodos x Price:

# %%
import matplotlib.pyplot as plt
datasetnovo.plot(kind='scatter',x='total_comodos',y='Price',alpha=0.1)
plt.axis([0,25.2,0,9234567])
plt.show()

# %% [markdown]
# #<b><font size=6 color=#FF0000>6. Resposta:</font></b>

# %% [markdown]
# <p align="justify">&emsp;<font size=5 color=#FF0000><b>Foi criada a variável "total_comodos" no item "5.1", contendo a soma dos números nas variáveis  banheiros, salas e quartos. E a correlação dessa nova variável "total_comodos" com a variável alvo (Price) foi baixa, deu um valor de 0,53.</b></font></p>
#
# <p align="justify">&emsp;<font size=5 color=#FF0000><b>Com esta correlação baixa, o aumento ou diminuição de total_comodos irá influenciar pouco na variável alvo (Price).</b></font></p>

# %% [markdown]
# <p align="justify">&emsp;
#
# </p>
